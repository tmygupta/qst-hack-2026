# %% [markdown]
# # QST Hackathon 2026 – Case 6: Non-Gaussian Quantum State Reconstruction

# %% [markdown]
# Objective: Generate a dataset of non-Gaussian continuous-variable quantum states (Wigner function images) using MrMustard, and train a convolutional neural network (CNN) to predict the quantum circuit parameters that produced those states.
# Pipeline:
# 1_Setup,
# 2_Data Generation,
# 3_CNN Model,
# 4_Training,
# 5_Evaluation

# %% [markdown]
# ## Setup

# %%
# Import required libraries
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from mrmustard.lab.states import SqueezedVacuum, Number
from mrmustard.lab.transformations import BSgate
from mrmustard.utils.wigner import wigner_discretized  # for Wigner function calculation:contentReference[oaicite:0]{index=0}
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)
torch.manual_seed(42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 11
#       9 from mrmustard.lab.states import SqueezedVacuum, Number
#      10 from mrmustard.lab.transformations import BSgate
# ---> 11 from mrmustard.utils.wigner import wigner_discretized  # for Wigner function calculation:contentReference[oaicite:0]{index=0}
#      12 import matplotlib.pyplot as plt
#      14 # Set random seed for reproducibility
#
# ModuleNotFoundError: No module named 'mrmustard.utils.wigner'
